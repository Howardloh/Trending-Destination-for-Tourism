# %%
# %run producer.py
# Out:
# Scraping Subreddit Submissions
# Kafka Producer has been initiated...
# Produced message on topic redditStreams - 0 - with value of 1c6nn7t
# Produced message on topic redditStreams - 1 - with value of 1c6o0yv
# Produced message on topic redditStreams - 2 - with value of 1c6en6w
# Produced message on topic redditStreams - 3 - with value of 1c6u5pn
# Produced message on topic redditStreams - 4 - with value of 1c6nlsb
# Produced message on topic redditStreams - 5 - with value of 1c6eber
# Produced message on topic redditStreams - 6 - with value of 1c6vi60
# Produced message on topic redditStreams - 7 - with value of 1c6ch76
# Produced message on topic redditStreams - 8 - with value of 1c6usyy
# Produced message on topic redditStreams - 9 - with value of 1c6y3nv
# Produced message on topic redditStreams - 10 - with value of 1c6xfax
# Produced message on topic redditStreams - 11 - with value of 1c6vag2
# Produced message on topic redditStreams - 12 - with value of 1c5w8ev
# ...
